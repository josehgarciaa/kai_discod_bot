# %%
import os

def create_structure():
    base_dir = "local_chatbot"
    
    # Define the file names and their initial content
    files = {
        "main.py": (
            "# Entry point of the application.\n"
            "# It initializes the chatbot, handles command-line arguments, and starts the chat session.\n\n"
            "if __name__ == '__main__':\n"
            "    print('Starting chatbot...')\n"
        ),
        "chat.py": (
            "# Contains the ChatBot class and functions that manage the chat session.\n\n"
            "class ChatBot:\n"
            "    def __init__(self):\n"
            "        self.chat_log = []\n\n"
            "    def start_chat(self):\n"
            "        print('Chat started...')\n"
        ),
        "storage.py": (
            "# Manages the chat register. This file handles saving and loading chat logs.\n\n"
            "def save_log(log):\n"
            "    # Implement saving the log to a file or database\n"
            "    pass\n\n"
            "def load_log():\n"
            "    # Implement loading the log from a file or database\n"
            "    pass\n"
        ),
        "models.py": (
            "# Interfaces with the OpenAI models.\n\n"
            "def get_response(prompt):\n"
            "    # Send prompt to the model and return its response\n"
            "    return 'response'\n"
        ),
        "admin.py": (
            "# Handles admin instructions.\n\n"
            "def process_admin_command(command):\n"
            "    # Process admin-specific commands or configurations\n"
            "    print(f'Processing admin command: {command}')\n"
        ),
        "utils.py": (
            "# Contains utility functions such as formatting messages and error handling.\n\n"
            "def format_message(msg):\n"
            "    return msg\n"
        ),
        "config.py": (
            "# Stores configuration settings like API keys, model parameters, and other global options.\n\n"
            "API_KEY = 'your_api_key_here'\n"
            "MODEL = 'gpt-3.5-turbo'\n"
        ),
        "README.md": (
            "# Local Chatbot\n\n"
            "This project implements a local chatbot based on OpenAI models.\n\n"
            "## Files and Structure\n"
            "- **main.py**: Entry point of the application.\n"
            "- **chat.py**: Core chat logic and ChatBot class.\n"
            "- **storage.py**: Chat logs saving and loading functionality.\n"
            "- **models.py**: Interface with OpenAI models.\n"
            "- **admin.py**: Processes admin instructions.\n"
            "- **utils.py**: Utility functions for the project.\n"
            "- **config.py**: Configuration settings.\n"
        )
    }

    # Create the base directory if it doesn't exist
    if not os.path.exists(base_dir):
        os.makedirs(base_dir)
        print(f"Created directory: {base_dir}")
    else:
        print(f"Directory already exists: {base_dir}")

    # Create each file with its corresponding content
    for filename, content in files.items():
        file_path = os.path.join(base_dir, filename)
        with open(file_path, "w", encoding="utf-8") as f:
            f.write(content)
        print(f"Created file: {file_path}")

if __name__ == '__main__':
    create_structure()
# Out:
# Created directory: local_chatbot
# Created file: local_chatbot\main.py
# Created file: local_chatbot\chat.py
# Created file: local_chatbot\storage.py
# Created file: local_chatbot\models.py
# Created file: local_chatbot\admin.py
# Created file: local_chatbot\utils.py
# Created file: local_chatbot\config.py
# Created file: local_chatbot\README.md
